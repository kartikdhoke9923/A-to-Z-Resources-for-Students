# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikdhoke9923/A-to-Z-Resources-for-Students/blob/master/aiday1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DAY 1 AI AND DEEP LEARNING

# %%
from sklearn.datasets import make_classification
import numpy as np
X,y= make_classification(n_samples=100, n_features=2, n_informative =1, # more that 1 column must be informative
                         n_redundant=0, n_classes=2, n_clusters_per_class=1, random_state=41,
                         hypercube=False,class_sep= 10)
# n_clusters_per_class - ?
# random_state- 41 - "?"

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter', s=100)  # here c is color and y i deciding colors

# %%
def perceptron(X,y):
  X = np.insert(X,0,1,axis=1)          # np.insert(array, index, value, axis)
  weights = np.ones(X.shape[1])
  lr = 0.1

  for i in range(1000):
    j=np.random.randint(0,100)
    y_hat = step(np.dot(X[j],weights))            # step - gif      z = w0​x0​ + w1​x1​ + w2​x2​  = np.dot(X[j],weights
    weights = weights + lr*(y[j]-y_hat)*X[j]

  return weights[0],weights[1:]

# %%
import matplotlib.pyplot as plt

# %%
def step(z):
    return 1 if z > 0 else 0

# %%
intercept_ , coef_ = perceptron(X,y)

# %%
m= -(coef_[0]/coef_[1])
b= -(intercept_/coef_[1])

# %%
x_input=np.linspace(-3,3,100)
y_input= m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input, y_input, color='red', linewidth=3 )
plt.scatter(X[:,0],X[:,1],c=y, cmap= 'winter' , s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
from sklearn.datasets import make_classification
import numpy as np
X,y= make_classification(n_samples=100, n_features=2, n_informative =1, # more that 1 column must be informative
                         n_redundant=0, n_classes=2, n_clusters_per_class=1, random_state=42,
                         hypercube=False,class_sep= 10)
# n_clusters_per_class - ?
# random_state- 41 - "?"

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter', s=100)  # here c is color and y i deciding colors

# %%
def perceptron(X,y):
  X = np.insert(X,0,1,axis=1)          # np.insert(array, index, value, axis)
  weights = np.ones(X.shape[1])
  lr = 0.1

  for i in range(1000):
    j=np.random.randint(0,100)
    y_hat = step(np.dot(X[j],weights))            # step - gif      z = w0​x0​ + w1​x1​ + w2​x2​  = np.dot(X[j],weights
    weights = weights + lr*(y[j]-y_hat)*X[j]

  return weights[0],weights[1:]

# %%
intercept_ , coef_ = perceptron(X,y)

# %%
m= -(coef_[0]/coef_[1])
b= -(intercept_/coef_[1])

# %%
x_input=np.linspace(-3,3,100)
y_input= m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input, y_input, color='red', linewidth=3 )
plt.scatter(X[:,0],X[:,1],c=y, cmap= 'winter' , s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
